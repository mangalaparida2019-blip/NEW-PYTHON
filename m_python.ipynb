# %% [markdown]
# <a href="https://colab.research.google.com/github/mangalaparida2019-blip/NEW-PYTHON/blob/main/m_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#---------python---------------------------------#

# %%
from IPython.core.compilerop import operator

"""variable is container where store data
 key_word is predefind words(words they have meaning previously in python)
 identifiers is basicaly name that we provide to variable/function/classes

RULES FOR NAMING
1.ALPHABATE(CAPITAL,SMALL),NUMBERS,underscore(_).

2.START WITH alphabateS,underscore(_).

3.space not allowed

4.case senstive means
EX:NAME="Do"
   name="did"

   print(NAME)
   print(name)
o/p = Do and did

5. you canot use key words
6.descriptive (means understand variable name)

comments: is unexcutable statements
single line comments using #
mulltiple line comments using """

"""operators

In Python, operators are symbols used to do operations on values or variables.
The values or variables are called operands.
Operators help us perform calculations and make decisions in a program.

a = 5
b = 3
print(a + b)

+ → operator

a and b → operands

1. Arithmetic Operators:Python arithmetic operators are used to do basic math operations on values.
+ (Addition)
- (Subtraction)
/ (divide)example, if a = 15, b = 4 => a / b = 15 / 4 = 3.75
* (Multiplication)
% (reminder)
** (Exponent) {power}example, if a = 2, b = 3 => a**b = 2**3 = 2^3 = 2*2*2 = 8
// (Floor division)example, if a = 15, b = 4 => a // b = 15 // 4 = 3
 here divide gives result in decimal but in floor division give roud of result

2. Assignment Operators
Assignment operators are used to give value to a variable.
Assignment operators = used to store or update value in a variable
= assign
+= → add and assign,if a = 15, b = 20 => a += b will be equal to a = a + b and therefore, a = 15 + 20 => a = 35

-= → subtract and assign, if a = 47, b = 32 => a -= b will be equal to a = a - b and therefore, a = 47 - 32 => a = 15

*= → multiply and assign

/= → divide and assign

%= → remainder and assign

//= → floor divide and assign

**= → power and assign
3. Comparison Operators
Comparison operators are used to compare two values.
They always give the result as True or False.

== → equal to

!= → not equal

> → greater than

< → less than

>= → greater than or equal

<= → less than or equal

4.Logical Operators
used to combine conditional statements.
AND
OR
NOT

5.Identity Operators:
used to compare the memory location of objects
is:If the references on both sides point to the same object,
it is determined to be true.
is not:If the references on both sides do not point at the same object,
it is determined to be true.

6.Bitwise Operators
used to manipulate individual bits of data
&-and
|-or
^-xor
~-not
<<-left shift
>>-right shift

DATA TYPES-



"""

# %%
monday = 85 #
tuesday = 64
avg = (monday+tuesday)/2

print(avg)
# Out:
# 74.5

# %%
a = 46    # Initializing the value of a
b = 4     # Initializing the value of b

print("For a =", a, "and b =", b,"\nCalculate the following:")

# printing different results
print('1. Addition of two numbers: a + b =', a + b)
print('2. Subtraction of two numbers: a - b =', a - b)
print('3. Multiplication of two numbers: a * b =', a * b)
print('4. Division of two numbers: a / b =', a / b)
print('5. Floor division of two numbers: a // b =',a // b)
print('6. Reminder of two numbers: a mod b =', a % b)
print('7. Exponent of two numbers: a ^ b =',a ** b)
# Out:
# For a = 46 and b = 4
# Calculate the following:
# 1. Addition of two numbers: a + b = 50
# 2. Subtraction of two numbers: a - b = 42
# 3. Multiplication of two numbers: a * b = 184
# 4. Division of two numbers: a / b = 11.5
# 5. Floor division of two numbers: a // b = 11
# 6. Reminder of two numbers: a mod b = 2
# 7. Exponent of two numbers: a ^ b = 4477456

# %%
#variable is container for a value
#strings
first_name = "John"
food = "puri"

print(f"hello {first_name}")
print(f"you like {food}")

#integers
